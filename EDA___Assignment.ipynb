# %% [markdown]
# #Assignment Code: DA-AG-009
# #EDA | Assignment

# %% [markdown]
# Question 1: Read the Bike Details dataset into a Pandas DataFrame and display its first 10 rows. Show the shape and column names as well.
#
# Answer:

# %%
import pandas as pd

df = pd.read_csv("bike_details.csv")

print("First 10 rows:")
print(df.head(10))

print("\nShape of dataset:")
print(df.shape)

print("\nColumn names:")
print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-488544619.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("bike_details.csv")
#       4
#       5 print("First 10 rows:")
#
# ...

# %% [markdown]
# Question 2: Check for missing values in all columns and describe your approach for handling them.
#
# Answer:

# %%
print("Missing values per column:")
print(df.isnull().sum())
# Out:
# Missing values per column:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2567113472.py in <cell line: 0>()
#       1 print("Missing values per column:")
# ----> 2 print(df.isnull().sum())
#
# NameError: name 'df' is not defined

# %% [markdown]
# Question 3: Plot the distribution of selling prices using a histogram and describe the overall trend.
#
# Answer:

# %%
import matplotlib.pyplot as plt

plt.hist(df['selling_price'], bins=30, edgecolor='black')
plt.xlabel("Selling Price")
plt.ylabel("Frequency")
plt.title("Distribution of Selling Prices")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2440289931.py in <cell line: 0>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 plt.hist(df['selling_price'], bins=30, edgecolor='black')
#       4 plt.xlabel("Selling Price")
#       5 plt.ylabel("Frequency")
#
# NameError: name 'df' is not defined

# %% [markdown]
# Question 4: Create a bar plot to visualize the average selling price for each seller_type and write one observation.
#
# Answer:

# %%
avg_price = df.groupby('seller_type')['selling_price'].mean()

avg_price.plot(kind='bar')
plt.ylabel("Average Selling Price")
plt.title("Average Selling Price by Seller Type")
plt.show()

# %% [markdown]
# Question 5: Compute the average km_driven for each ownership type and present the result as a bar plot.
#
# Answer:

# %%
avg_km = df.groupby('owner')['km_driven'].mean()

avg_km.plot(kind='bar')
plt.ylabel("Average KM Driven")
plt.title("Average KM Driven by Ownership Type")
plt.show()

# %% [markdown]
# Question 6: Use the IQR method to detect and remove outliers from the km_driven column. Show before-and-after summary statistics.
#
# Answer:

# %%
print("Before removing outliers:")
print(df['km_driven'].describe())

Q1 = df['km_driven'].quantile(0.25)
Q3 = df['km_driven'].quantile(0.75)
IQR = Q3 - Q1

df_no_outliers = df[(df['km_driven'] >= Q1 - 1.5 * IQR) &
                    (df['km_driven'] <= Q3 + 1.5 * IQR)]

print("\nAfter removing outliers:")
print(df_no_outliers['km_driven'].describe())

# %% [markdown]
# Question 7: Create a scatter plot of year vs. selling_price to explore the relationship between a bike's age and its price.
#
# Answer:

# %%
plt.scatter(df['year'], df['selling_price'])
plt.xlabel("Year")
plt.ylabel("Selling Price")
plt.title("Year vs Selling Price")
plt.show()

# %% [markdown]
# Question 8: Convert the seller_type column into numeric format using one-hot encoding and display the first 5 rows.
#
# Answer:

# %%
df_encoded = pd.get_dummies(df, columns=['seller_type'])
print(df_encoded.head())

# %% [markdown]
# Question 9: Generate a heatmap of the correlation matrix for all numeric columns. What correlations stand out the most?
#
# Answer:

# %%
import seaborn as sns

plt.figure(figsize=(8,6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Question 10: Summarize your findings in a brief report.
#
# Answer:
# The most important factors affecting a bike’s selling price are the year of manufacture, kilometers driven, and seller type. Newer bikes with fewer kilometers tend to sell at higher prices. Dealer listings also generally command higher prices.
#
# Data cleaning steps included handling missing values, removing outliers using the IQR method, and encoding categorical variables using one-hot encoding. Feature engineering improved data quality and prepared the dataset for further modeling.
#
# Sample code reference:

# %%
print("Data cleaned, encoded, and ready for modeling.")
# Out:
# Data cleaned, encoded, and ready for modeling.
